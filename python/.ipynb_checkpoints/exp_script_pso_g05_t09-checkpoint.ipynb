# [1. 0. 0.] <-> [0.7237217  0.11194056 0.16433783]
# [0. 1. 0.] <-> [0.427589   0.54257727 0.02983377]
# [1. 0. 0.] <-> [0.8462711  0.08831234 0.06541657]
# [0. 1. 0.] <-> [0.38103443 0.59711385 0.02185169]
# [1. 0. 0.] <-> [0.785146   0.10435066 0.1105033 ]
# [1. 0. 0.] <-> [0.813889   0.06086366 0.1252473 ]
# [1. 0. 0.] <-> [0.78439796 0.13301446 0.08258758]
# [0. 1. 0.] <-> [0.6436913  0.3151757  0.04113305]
# [0. 0. 1.] <-> [0.19221535 0.01934222 0.78844243]
# [1. 0. 0.] <-> [0.8542123  0.06935059 0.07643715]
# [1. 0. 0.] <-> [0.78885883 0.15358967 0.05755149]
# [0. 1. 0.] <-> [0.5864898  0.3108102  0.10270001]
# [1. 0. 0.] <-> [0.83909166 0.032097   0.12881133]
# [1. 0. 0.] <-> [0.8488717  0.07819834 0.07292999]
# [1. 0. 0.] <-> [0.7244347  0.21311705 0.06244822]
# [1. 0. 0.] <-> [0.7597646  0.13609113 0.10414423]
# [0. 1. 0.] <-> [0.21385086 0.7603021  0.02584704]
# [1. 0. 0.] <-> [0.80858886 0.10777548 0.08363561]
# [1. 0. 0.] <-> [0.8011784  0.0965136  0.10230799]
# [0. 0. 1.] <-> [0.22161682 0.02073188 0.75765127]
# [0. 1. 0.] <-> [0.4672404  0.45106298 0.08169666]
# [1. 0. 0.] <-> [0.8014842  0.04080018 0.15771559]
# [1. 0. 0.] <-> [0.83588797 0.03856222 0.12554981]
# [1. 0. 0.] <-> [0.8535591  0.0649026  0.08153827]
# [1. 0. 0.] <-> [0.78485686 0.04399787 0.17114528]
# [1. 0. 0.] <-> [0.8380981  0.10749274 0.05440906]
# [1. 0. 0.] <-> [0.80929804 0.08399685 0.10670511]
# [1. 0. 0.] <-> [0.8210673  0.08333807 0.09559463]
# [1. 0. 0.] <-> [0.77014804 0.1517682  0.07808376]
# [0. 0. 1.] <-> [0.23233381 0.0207206  0.74694556]
# [0. 0. 1.] <-> [0.5686175  0.01740518 0.41397732]
# [0. 1. 0.] <-> [0.63812584 0.30923855 0.05263567]
# [1. 0. 0.] <-> [0.8024144  0.08239459 0.11519102]
# [0. 1. 0.] <-> [0.6023971  0.36912552 0.02847742]
# [1. 0. 0.] <-> [0.7897332  0.07700812 0.13325876]
# [1. 0. 0.] <-> [0.8254302  0.05108197 0.12348779]
# [0. 1. 0.] <-> [0.46717912 0.51006526 0.02275557]
# [1. 0. 0.] <-> [0.85341257 0.05640078 0.09018663]
# [1. 0. 0.] <-> [0.69867355 0.0365464  0.26478   ]
# [1. 0. 0.] <-> [0.78292996 0.06008749 0.15698263]
# [0. 1. 0.] <-> [0.69144183 0.26720017 0.04135802]
# [1. 0. 0.] <-> [0.7457254  0.19561459 0.05865997]
# [0. 0. 1.] <-> [0.8177029  0.03959877 0.14269832]
# [1. 0. 0.] <-> [0.79585934 0.08615939 0.11798129]
# [1. 0. 0.] <-> [0.77747595 0.08781969 0.13470434]
# [1. 0. 0.] <-> [0.8541151  0.03766106 0.10822382]
# [1. 0. 0.] <-> [0.7976049  0.10109114 0.10130399]
# [1. 0. 0.] <-> [0.8319401  0.09942909 0.06863075]
# [0. 1. 0.] <-> [0.2081249  0.7632548  0.02862026]
# [0. 1. 0.] <-> [0.23117359 0.74216527 0.02666114]
# [1. 0. 0.] <-> [0.7853324  0.0332059  0.18146175]
# [1. 0. 0.] <-> [0.8064888  0.10452115 0.08898994]
# [1. 0. 0.] <-> [0.8606514  0.039597   0.09975155]
# [1. 0. 0.] <-> [0.83287376 0.08267417 0.084452  ]
# [0. 1. 0.] <-> [0.6331944  0.33644018 0.03036537]
# [1. 0. 0.] <-> [0.81266904 0.04015044 0.14718048]
# [1. 0. 0.] <-> [0.5938334  0.04563034 0.36053634]
# [1. 0. 0.] <-> [0.851119   0.0847323  0.06414872]
# [1. 0. 0.] <-> [0.81835735 0.0950673  0.08657528]
# [1. 0. 0.] <-> [0.799523   0.10251748 0.09795949]
# [0. 0. 1.] <-> [0.49486738 0.01781567 0.48731694]
# [0. 1. 0.] <-> [0.7331717  0.23140918 0.0354191 ]
# [1. 0. 0.] <-> [0.7399421  0.10694034 0.1531176 ]
# [1. 0. 0.] <-> [0.75367665 0.06149051 0.18483278]
# [0. 0. 1.] <-> [0.35870448 0.02218123 0.61911434]
# [1. 0. 0.] <-> [0.80788785 0.10143098 0.09068117]
# [1. 0. 0.] <-> [0.8574611  0.05967611 0.08286279]
# [1. 0. 0.] <-> [0.78654695 0.07388317 0.1395699 ]
# [1. 0. 0.] <-> [0.83332527 0.03950418 0.12717058]
# [1. 0. 0.] <-> [0.7953095  0.11141816 0.09327243]
# [0. 0. 1.] <-> [0.8002848  0.04110499 0.15861017]
# [0. 1. 0.] <-> [0.24579215 0.7293008  0.02490699]
# [1. 0. 0.] <-> [0.82297945 0.09878191 0.07823873]
# [1. 0. 0.] <-> [0.76325256 0.10800484 0.1287426 ]
# [1. 0. 0.] <-> [0.76069796 0.04635851 0.19294359]
# [0. 0. 1.] <-> [0.5716768  0.01829618 0.4100271 ]
# [1. 0. 0.] <-> [0.80020565 0.05181163 0.14798267]
# [1. 0. 0.] <-> [0.80717295 0.04048109 0.15234588]
# [0. 0. 1.] <-> [0.3114603  0.03181014 0.6567296 ]
# [0. 0. 1.] <-> [0.2229387  0.02042488 0.7566364 ]
# [0. 1. 0.] <-> [0.25837064 0.7151101  0.02651925]
# [1. 0. 0.] <-> [0.78943545 0.06668239 0.14388216]
# [1. 0. 0.] <-> [0.81293994 0.12432121 0.06273883]
# {'accuracy': 0.9135802469135802, 'mean_square_error': 0.19319758930017542, 'categorical_crossentropy': 0.3757117236102069, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 14, 'tn_hit': 18, 'fn_hit': 0}, 1: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 8}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}}

# %%
train_acc = [h['accuracy'] for h in history]
train_mse = [h['mean_square_error'] for h in history]
train_cce = [h['categorical_crossentropy'] for h in history]

# %%
draw_plot(x = [[i for i in range(len(history))], [(i+1)*breakpoint for i in range(len(checkpoints))]], y_list = [train_cce, [ ckp[model.loss_fn] for ckp in checkpoints ]], x_label = 'Epochs', \
    y_label = model.loss_fn, legend=['train', 'test'])
acc = [ ckp['accuracy'] for ckp in checkpoints ]
draw_plot(x = [[i for i in range(len(history))], [(i+1)*breakpoint for i in range(len(checkpoints))]], y_list = [train_acc, acc], x_label = 'Checkpoints', \
    y_label = 'accuracy', legend=['train', 'test'])

# %%
for checkpoint in checkpoints:
    print(checkpoint, '\n\n')
# Out:
# {'accuracy': 0.8580246913580247, 'mean_square_error': 0.3425588612584916, 'categorical_crossentropy': 0.5507182015313042, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 23, 'tn_hit': 9, 'fn_hit': 0}, 1: {'tp_hit': 0, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 17}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 10}
#
#
# {'accuracy': 0.8271604938271605, 'mean_square_error': 0.403067900605619, 'categorical_crossentropy': 0.6810256110297309, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 28, 'tn_hit': 4, 'fn_hit': 0}, 1: {'tp_hit': 0, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 17}, 2: {'tp_hit': 4, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 11}}, 'checkpoint': 20}
#
#
# {'accuracy': 0.8333333333333334, 'mean_square_error': 0.3535525408420086, 'categorical_crossentropy': 0.6211138124819156, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 25, 'tn_hit': 7, 'fn_hit': 0}, 1: {'tp_hit': 1, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 16}, 2: {'tp_hit': 4, 'fp_hit': 2, 'tn_hit': 91, 'fn_hit': 11}}, 'checkpoint': 30}
#
#
# {'accuracy': 0.8703703703703703, 'mean_square_error': 0.3442759551143805, 'categorical_crossentropy': 0.6035883868182147, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 21, 'tn_hit': 11, 'fn_hit': 0}, 1: {'tp_hit': 8, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 9}, 2: {'tp_hit': 3, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 12}}, 'checkpoint': 40}
#
#
# {'accuracy': 0.8580246913580247, 'mean_square_error': 0.36723304210041063, 'categorical_crossentropy': 0.6193363754837601, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 23, 'tn_hit': 9, 'fn_hit': 0}, 1: {'tp_hit': 0, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 17}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 50}
#
#
# {'accuracy': 0.845679012345679, 'mean_square_error': 0.3298401318702129, 'categorical_crossentropy': 0.5558972535309968, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 25, 'tn_hit': 7, 'fn_hit': 0}, 1: {'tp_hit': 0, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 17}, 2: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 8}}, 'checkpoint': 60}
#
#
# {'accuracy': 0.9135802469135802, 'mean_square_error': 0.28175977164479565, 'categorical_crossentropy': 0.5086690408212168, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 14, 'tn_hit': 18, 'fn_hit': 0}, 1: {'tp_hit': 8, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 9}, 2: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 5}}, 'checkpoint': 70}
#
#
# {'accuracy': 0.8518518518518519, 'mean_square_error': 0.28200788769747054, 'categorical_crossentropy': 0.48534781844527636, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 24, 'tn_hit': 8, 'fn_hit': 0}, 1: {'tp_hit': 6, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 11}, 2: {'tp_hit': 2, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 13}}, 'checkpoint': 80}
#
#
# {'accuracy': 0.8950617283950617, 'mean_square_error': 0.23375620832636027, 'categorical_crossentropy': 0.4251248041788737, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 17, 'tn_hit': 15, 'fn_hit': 0}, 1: {'tp_hit': 8, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 9}, 2: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 8}}, 'checkpoint': 90}
#
#
# {'accuracy': 0.9012345679012346, 'mean_square_error': 0.2279221043919181, 'categorical_crossentropy': 0.42220659609194156, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 16, 'tn_hit': 16, 'fn_hit': 0}, 1: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 10}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 100}
#
#
# {'accuracy': 0.9444444444444444, 'mean_square_error': 0.19627085309050132, 'categorical_crossentropy': 0.3870840072631836, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 9, 'tn_hit': 23, 'fn_hit': 0}, 1: {'tp_hit': 11, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 6}, 2: {'tp_hit': 12, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 3}}, 'checkpoint': 110}
#
#
# {'accuracy': 0.9074074074074074, 'mean_square_error': 0.22451396040400176, 'categorical_crossentropy': 0.41931597391764325, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 15, 'tn_hit': 17, 'fn_hit': 0}, 1: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 10}, 2: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 5}}, 'checkpoint': 120}
#
#
# {'accuracy': 0.9074074074074074, 'mean_square_error': 0.21504251903742816, 'categorical_crossentropy': 0.4082033369276259, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 15, 'tn_hit': 17, 'fn_hit': 0}, 1: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 10}, 2: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 5}}, 'checkpoint': 130}
#
#
# {'accuracy': 0.9012345679012346, 'mean_square_error': 0.20887553144361284, 'categorical_crossentropy': 0.393911220409252, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 16, 'tn_hit': 16, 'fn_hit': 0}, 1: {'tp_hit': 7, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 10}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 140}
#
#
# {'accuracy': 0.9197530864197531, 'mean_square_error': 0.1903073132392002, 'categorical_crossentropy': 0.37727140497278283, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 13, 'tn_hit': 19, 'fn_hit': 0}, 1: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 7}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 150}
#
#
# {'accuracy': 0.9135802469135802, 'mean_square_error': 0.1957313371589052, 'categorical_crossentropy': 0.37378590195267286, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 14, 'tn_hit': 18, 'fn_hit': 0}, 1: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 8}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 160}
#
#
# {'accuracy': 0.9135802469135802, 'mean_square_error': 0.1957313371589052, 'categorical_crossentropy': 0.37378590195267286, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 14, 'tn_hit': 18, 'fn_hit': 0}, 1: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 8}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 170}
#
#
# {'accuracy': 0.9197530864197531, 'mean_square_error': 0.19747866622760113, 'categorical_crossentropy': 0.3772773742675781, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 13, 'tn_hit': 19, 'fn_hit': 0}, 1: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 8}, 2: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 5}}, 'checkpoint': 180}
#
#
# {'accuracy': 0.9197530864197531, 'mean_square_error': 0.18813536077542933, 'categorical_crossentropy': 0.3711836073133681, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 13, 'tn_hit': 19, 'fn_hit': 0}, 1: {'tp_hit': 10, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 7}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 190}
#
#
# {'accuracy': 0.9135802469135802, 'mean_square_error': 0.19319758930017542, 'categorical_crossentropy': 0.3757117236102069, 'essential_metrics': {0: {'tp_hit': 76, 'fp_hit': 14, 'tn_hit': 18, 'fn_hit': 0}, 1: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 91, 'fn_hit': 8}, 2: {'tp_hit': 9, 'fp_hit': 0, 'tn_hit': 93, 'fn_hit': 6}}, 'checkpoint': 200}

# %%
print(model)
# Out:
# Layer 1
# Neuron 0: weights:
# [ 0.4726789  -0.55974823 -0.17631593  0.5276909   0.6252378 ]
#  bias: -0.32879945635795593
#
# Neuron 1: weights:
# [-0.08824745 -0.4206203  -0.79295367 -0.95300066 -0.6800443 ]
#  bias: 0.35114315152168274
#
# Neuron 2: weights:
# [ 0.6476306  -0.97398263 -0.671721   -0.30349743  0.2838902 ]
#  bias: 0.5268808603286743
#
# Neuron 3: weights:
# [-0.46294665  0.9696754   0.33158118 -0.17111193 -0.42544895]
#  bias: 0.25624120235443115
#
# $
# Layer 2
# Neuron 0: weights:
# [-0.35542378  1.3680311   0.63933223 -0.01975528]
#  bias: 0.012254791334271431
#
# Neuron 1: weights:
# [-0.9090665  -0.77924573 -1.4316024   1.2219104 ]
#  bias: 0.30901268124580383
#
# Neuron 2: weights:
# [ 1.2639966 -1.027479   0.7439313 -1.5779829]
#  bias: -0.2717432677745819
#
# $
